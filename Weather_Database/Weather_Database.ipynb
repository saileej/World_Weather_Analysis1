# %%
# Dependencies
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
from datetime import datetime
import requests
import time
from scipy.stats import linregress
import gmaps

# %%
#Weather API key
weather_api_key="7b94ca86319b453da399c67dc19912a2"

# Google API Key
g_key = "AIzaSyA4agfLEJL78LGM4Yb0HEue9edH8Cgj-5E"

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 763

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#loop through cities in list
for i, city in enumerate(cities):
    
    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #create URL endpoint for city
    city_url = url + '&q=' + city.replace(" ","+")
    
    #log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # add 1 to record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_dc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_dc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | castro
# Processing Record 2 of Set 1 | port elizabeth
# Processing Record 3 of Set 1 | provideniya
# Processing Record 4 of Set 1 | hamilton
# Processing Record 5 of Set 1 | hithadhoo
# Processing Record 6 of Set 1 | agua verde
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | maniitsoq
# Processing Record 10 of Set 1 | ternate
# Processing Record 11 of Set 1 | kruisfontein
# Processing Record 12 of Set 1 | bengkulu
# Processing Record 13 of Set 1 | bambous virieux
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | bredasdorp
# Processing Record 18 of Set 1 | airai
# Processing Record 19 of Set 1 | honningsvag
# Processing Record 20 of Set 1 | hermanus
# Processing Record 21 of Set 1 | rio grande
# Processing Record 22 of Set 1 | filingue
# Processing Record 23 of Set 1 | ventosa
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | louis trichardt
# Processing Record 26 of Set 1 | carballo
# Processing Record 27 of Set 1 | tabuk
# Processing Record 28 of Set 1 | aklavik
# Processing Record 29 of Set 1 | bandarbeyla
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | port alfred
# Processing Record 33 of Set 1 | nova olinda do norte
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | harper
# Processing Record 36 of Set 1 | souillac
# Processing Record 37 of Set 1 | mount isa
# Processing Record 38 of Set 1 | ostrovnoy
# Processing Record 39 of Set 1 | hobart
# Processing Record 40 of Set 1 | shenjiamen
# Processing Record 41 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 1 | biltine
# Processing Record 43 of Set 1 | nanortalik
# Processing Record 44 of Set 1 | vaini
# Processing Record 45 of Set 1 | cherskiy
# Processing Record 46 of Set 1 | aljezur
# Processing Record 47 of Set 1 | bremervorde
# Processing Record 48 of Set 1 | bunia
# Processing Record 49 of Set 1 | iserlohn
# Processing Record 50 of Set 1 | avarua
# Processing Record 1 of Set 2 | new norfolk
# Processing Record 2 of Set 2 | sechura
# Processing Record 3 of Set 2 | esfahan
# Processing Record 4 of Set 2 | brainerd
# Processing Record 5 of Set 2 | asau
# Processing Record 6 of Set 2 | lerwick
# Processing Record 7 of Set 2 | ponta do sol
# Processing Record 8 of Set 2 | faanui
# Processing Record 9 of Set 2 | nishihara
# Processing Record 10 of Set 2 | tuatapere
# Processing Record 11 of Set 2 | klaksvik
# Processing Record 12 of Set 2 | alyangula
# Processing Record 13 of Set 2 | dongying
# Processing Record 14 of Set 2 | ahipara
# Processing Record 15 of Set 2 | olinda
# Processing Record 16 of Set 2 | beringovskiy
# Processing Record 17 of Set 2 | barrow
# Processing Record 18 of Set 2 | turukhansk
# Processing Record 19 of Set 2 | maputo
# Processing Record 20 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 2 | moussoro
# Processing Record 22 of Set 2 | tasiilaq
# Processing Record 23 of Set 2 | neftcala
# Processing Record 24 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 25 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 2 | thompson
# Processing Record 27 of Set 2 | romny
# Processing Record 28 of Set 2 | thinadhoo
# Processing Record 29 of Set 2 | bouna
# Processing Record 30 of Set 2 | acarau
# Processing Record 31 of Set 2 | ilulissat
# Processing Record 32 of Set 2 | clyde river
# Processing Record 33 of Set 2 | mahibadhoo
# Processing Record 34 of Set 2 | qaanaaq
# Processing Record 35 of Set 2 | san vicente
# Processing Record 36 of Set 2 | arraial do cabo
# Processing Record 37 of Set 2 | hilo
# Processing Record 38 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 40 of Set 2 | boma
# Processing Record 41 of Set 2 | goderich
# Processing Record 42 of Set 2 | saint-philippe
# Processing Record 43 of Set 2 | rongcheng
# Processing Record 44 of Set 2 | isangel
# Processing Record 45 of Set 2 | grindavik
# Processing Record 46 of Set 2 | male
# Processing Record 47 of Set 2 | constitucion
# Processing Record 48 of Set 2 | torbay
# Processing Record 49 of Set 2 | rocha
# Processing Record 50 of Set 2 | victoria
# Processing Record 1 of Set 3 | kahului
# Processing Record 2 of Set 3 | awjilah
# Processing Record 3 of Set 3 | gillette
# Processing Record 4 of Set 3 | geraldton
# Processing Record 5 of Set 3 | anadyr
# Processing Record 6 of Set 3 | mastic beach
# Processing Record 7 of Set 3 | punta arenas
# Processing Record 8 of Set 3 | ridgecrest
# Processing Record 9 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 3 | san rafael
# Processing Record 11 of Set 3 | vao
# Processing Record 12 of Set 3 | kutum
# Processing Record 13 of Set 3 | fort nelson
# Processing Record 14 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 16 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 3 | poum
# Processing Record 18 of Set 3 | pevek
# Processing Record 19 of Set 3 | palmer
# Processing Record 20 of Set 3 | abu samrah
# Processing Record 21 of Set 3 | diffa
# Processing Record 22 of Set 3 | ingham
# Processing Record 23 of Set 3 | barra da estiva
# Processing Record 24 of Set 3 | comodoro rivadavia
# Processing Record 25 of Set 3 | lorengau
# Processing Record 26 of Set 3 | birjand
# Processing Record 27 of Set 3 | bluff
# Processing Record 28 of Set 3 | carnarvon
# Processing Record 29 of Set 3 | pecanha
# Processing Record 30 of Set 3 | karamea
# City not found. Skipping...
# Processing Record 31 of Set 3 | mattru
# Processing Record 32 of Set 3 | meulaboh
# Processing Record 33 of Set 3 | boa vista
# Processing Record 34 of Set 3 | arani
# Processing Record 35 of Set 3 | lososina
# Processing Record 36 of Set 3 | trinidad
# Processing Record 37 of Set 3 | nacala
# Processing Record 38 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 3 | griffith
# Processing Record 40 of Set 3 | hovd
# Processing Record 41 of Set 3 | pokrovsk
# Processing Record 42 of Set 3 | barbacoas
# Processing Record 43 of Set 3 | santiago
# Processing Record 44 of Set 3 | raha
# Processing Record 45 of Set 3 | chokurdakh
# Processing Record 46 of Set 3 | kendari
# Processing Record 47 of Set 3 | komsomolskiy
# Processing Record 48 of Set 3 | wahran
# City not found. Skipping...
# Processing Record 49 of Set 3 | ongandjera
# Processing Record 50 of Set 3 | yomitan
# City not found. Skipping...
# Processing Record 1 of Set 4 | kaitangata
# Processing Record 2 of Set 4 | marmora
# Processing Record 3 of Set 4 | yar-sale
# Processing Record 4 of Set 4 | norman wells
# Processing Record 5 of Set 4 | bathsheba
# Processing Record 6 of Set 4 | alghero
# Processing Record 7 of Set 4 | brae
# Processing Record 8 of Set 4 | tottori
# Processing Record 9 of Set 4 | ancud
# Processing Record 10 of Set 4 | yellowknife
# Processing Record 11 of Set 4 | conde
# Processing Record 12 of Set 4 | lebu
# Processing Record 13 of Set 4 | san policarpo
# Processing Record 14 of Set 4 | monrovia
# Processing Record 15 of Set 4 | nikolskoye
# Processing Record 16 of Set 4 | nome
# Processing Record 17 of Set 4 | tuktoyaktuk
# Processing Record 18 of Set 4 | port augusta
# Processing Record 19 of Set 4 | karratha
# Processing Record 20 of Set 4 | mykhaylivka
# Processing Record 21 of Set 4 | ranong
# Processing Record 22 of Set 4 | butaritari
# Processing Record 23 of Set 4 | vostok
# Processing Record 24 of Set 4 | san andres
# Processing Record 25 of Set 4 | vila
# Processing Record 26 of Set 4 | pedernales
# Processing Record 27 of Set 4 | wanning
# Processing Record 28 of Set 4 | barao de melgaco
# Processing Record 29 of Set 4 | saint anthony
# Processing Record 30 of Set 4 | east london
# Processing Record 31 of Set 4 | puerto ayora
# Processing Record 32 of Set 4 | antalaha
# Processing Record 33 of Set 4 | alice
# Processing Record 34 of Set 4 | hami
# Processing Record 35 of Set 4 | hazorasp
# Processing Record 36 of Set 4 | kavieng
# Processing Record 37 of Set 4 | palauig
# Processing Record 38 of Set 4 | itarema
# Processing Record 39 of Set 4 | temaraia
# City not found. Skipping...
# Processing Record 40 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 4 | buraydah
# Processing Record 42 of Set 4 | mpanda
# Processing Record 43 of Set 4 | vyartsilya
# Processing Record 44 of Set 4 | kasongo-lunda
# Processing Record 45 of Set 4 | tura
# Processing Record 46 of Set 4 | gunjur
# Processing Record 47 of Set 4 | letka
# Processing Record 48 of Set 4 | luganville
# Processing Record 49 of Set 4 | tapaua
# City not found. Skipping...
# Processing Record 50 of Set 4 | hirara
# Processing Record 1 of Set 5 | chern
# Processing Record 2 of Set 5 | dikson
# Processing Record 3 of Set 5 | upernavik
# Processing Record 4 of Set 5 | klyuchi
# Processing Record 5 of Set 5 | port blair
# Processing Record 6 of Set 5 | saldanha
# Processing Record 7 of Set 5 | newton
# Processing Record 8 of Set 5 | russell
# Processing Record 9 of Set 5 | ribeira grande
# Processing Record 10 of Set 5 | pembroke
# Processing Record 11 of Set 5 | vila velha
# Processing Record 12 of Set 5 | abeche
# Processing Record 13 of Set 5 | sandpoint
# Processing Record 14 of Set 5 | chuy
# Processing Record 15 of Set 5 | hambantota
# Processing Record 16 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 17 of Set 5 | walvis bay
# Processing Record 18 of Set 5 | saskylakh
# Processing Record 19 of Set 5 | longyearbyen
# Processing Record 20 of Set 5 | sheopur
# Processing Record 21 of Set 5 | ankang
# Processing Record 22 of Set 5 | hailun
# Processing Record 23 of Set 5 | bintulu
# Processing Record 24 of Set 5 | bosaso
# Processing Record 25 of Set 5 | praia
# Processing Record 26 of Set 5 | biaora
# Processing Record 27 of Set 5 | merauke
# Processing Record 28 of Set 5 | korla
# Processing Record 29 of Set 5 | college
# Processing Record 30 of Set 5 | banda aceh
# Processing Record 31 of Set 5 | port hedland
# Processing Record 32 of Set 5 | kathmandu
# Processing Record 33 of Set 5 | churapcha
# Processing Record 34 of Set 5 | la ronge
# Processing Record 35 of Set 5 | qui nhon
# Processing Record 36 of Set 5 | margate
# Processing Record 37 of Set 5 | barinas
# Processing Record 38 of Set 5 | salalah
# Processing Record 39 of Set 5 | lompoc
# Processing Record 40 of Set 5 | gold coast
# Processing Record 41 of Set 5 | tutoia
# Processing Record 42 of Set 5 | pastavy
# Processing Record 43 of Set 5 | leningradskiy
# Processing Record 44 of Set 5 | sao felix do xingu
# Processing Record 45 of Set 5 | usinsk
# Processing Record 46 of Set 5 | yumen
# Processing Record 47 of Set 5 | necochea
# Processing Record 48 of Set 5 | mullaitivu
# City not found. Skipping...
# Processing Record 49 of Set 5 | lagoa
# Processing Record 50 of Set 5 | mahebourg
# Processing Record 1 of Set 6 | pisco
# Processing Record 2 of Set 6 | khandbari
# Processing Record 3 of Set 6 | nuuk
# Processing Record 4 of Set 6 | atambua
# Processing Record 5 of Set 6 | miri
# Processing Record 6 of Set 6 | bonthe
# Processing Record 7 of Set 6 | ghimes-faget
# Processing Record 8 of Set 6 | keffi
# Processing Record 9 of Set 6 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 10 of Set 6 | hervey bay
# Processing Record 11 of Set 6 | iqaluit
# Processing Record 12 of Set 6 | megion
# Processing Record 13 of Set 6 | iquique
# Processing Record 14 of Set 6 | kandi
# Processing Record 15 of Set 6 | beira
# Processing Record 16 of Set 6 | pindiga
# Processing Record 17 of Set 6 | san cristobal
# Processing Record 18 of Set 6 | broome
# Processing Record 19 of Set 6 | boguchany
# Processing Record 20 of Set 6 | saint george
# Processing Record 21 of Set 6 | mana
# Processing Record 22 of Set 6 | wanaka
# Processing Record 23 of Set 6 | sakakah
# Processing Record 24 of Set 6 | coquimbo
# Processing Record 25 of Set 6 | fairbanks
# Processing Record 26 of Set 6 | solvychegodsk
# Processing Record 27 of Set 6 | green river
# Processing Record 28 of Set 6 | mnogovershinnyy
# Processing Record 29 of Set 6 | touros
# Processing Record 30 of Set 6 | ekibastuz
# Processing Record 31 of Set 6 | bulancak
# Processing Record 32 of Set 6 | qaqortoq
# Processing Record 33 of Set 6 | vangaindrano
# Processing Record 34 of Set 6 | calama
# Processing Record 35 of Set 6 | esperance
# Processing Record 36 of Set 6 | biak
# Processing Record 37 of Set 6 | hasaki
# Processing Record 38 of Set 6 | sao filipe
# Processing Record 39 of Set 6 | husavik
# Processing Record 40 of Set 6 | santander
# Processing Record 41 of Set 6 | houma
# Processing Record 42 of Set 6 | kungurtug
# Processing Record 43 of Set 6 | mar del plata
# Processing Record 44 of Set 6 | russellville
# Processing Record 45 of Set 6 | luderitz
# Processing Record 46 of Set 6 | one hundred mile house
# City not found. Skipping...
# Processing Record 47 of Set 6 | ugoofaaru
# Processing Record 48 of Set 6 | gamba
# Processing Record 49 of Set 6 | tonj
# Processing Record 50 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 7 | port lincoln
# Processing Record 2 of Set 7 | ballina
# Processing Record 3 of Set 7 | rawson
# Processing Record 4 of Set 7 | cape town
# Processing Record 5 of Set 7 | puerto gaitan
# Processing Record 6 of Set 7 | alexander city
# Processing Record 7 of Set 7 | bubaque
# Processing Record 8 of Set 7 | mayumba
# Processing Record 9 of Set 7 | port moresby
# Processing Record 10 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 7 | nemuro
# Processing Record 12 of Set 7 | inhambane
# Processing Record 13 of Set 7 | raudeberg
# Processing Record 14 of Set 7 | sioux lookout
# Processing Record 15 of Set 7 | san ramon
# Processing Record 16 of Set 7 | khatanga
# Processing Record 17 of Set 7 | lavrentiya
# Processing Record 18 of Set 7 | muisne
# Processing Record 19 of Set 7 | itaperucu
# Processing Record 20 of Set 7 | palaikastron
# Processing Record 21 of Set 7 | codrington
# Processing Record 22 of Set 7 | penzance
# Processing Record 23 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 24 of Set 7 | konstantinovka
# Processing Record 25 of Set 7 | alice springs
# Processing Record 26 of Set 7 | nyakabindi
# Processing Record 27 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 7 | santa isabel do rio negro
# Processing Record 29 of Set 7 | aksu
# Processing Record 30 of Set 7 | kochi
# Processing Record 31 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 32 of Set 7 | kokhma
# Processing Record 33 of Set 7 | painesville
# Processing Record 34 of Set 7 | vung tau
# Processing Record 35 of Set 7 | boende
# Processing Record 36 of Set 7 | mvuma
# Processing Record 37 of Set 7 | nioro
# Processing Record 38 of Set 7 | dorchester
# Processing Record 39 of Set 7 | mezen
# Processing Record 40 of Set 7 | jitra
# Processing Record 41 of Set 7 | whitianga
# Processing Record 42 of Set 7 | trelew
# Processing Record 43 of Set 7 | muros
# Processing Record 44 of Set 7 | ikongo
# Processing Record 45 of Set 7 | avera
# Processing Record 46 of Set 7 | namatanai
# Processing Record 47 of Set 7 | marmande
# Processing Record 48 of Set 7 | ahuimanu
# Processing Record 49 of Set 7 | tiznit
# Processing Record 50 of Set 7 | shimoda
# Processing Record 1 of Set 8 | bushehr
# Processing Record 2 of Set 8 | neuquen
# Processing Record 3 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 4 of Set 8 | ambon
# Processing Record 5 of Set 8 | catacocha
# Processing Record 6 of Set 8 | ewa beach
# Processing Record 7 of Set 8 | saint-pierre
# Processing Record 8 of Set 8 | mudgee
# Processing Record 9 of Set 8 | otautau
# Processing Record 10 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 11 of Set 8 | okitipupa
# Processing Record 12 of Set 8 | hisai
# Processing Record 13 of Set 8 | shaunavon
# Processing Record 14 of Set 8 | san antonio
# Processing Record 15 of Set 8 | skibbereen
# Processing Record 16 of Set 8 | camacha
# Processing Record 17 of Set 8 | warmbad
# Processing Record 18 of Set 8 | campbell river
# Processing Record 19 of Set 8 | bambanglipuro
# Processing Record 20 of Set 8 | kudahuvadhoo
# Processing Record 21 of Set 8 | bestobe
# Processing Record 22 of Set 8 | rehoboth
# Processing Record 23 of Set 8 | akonolinga
# Processing Record 24 of Set 8 | galle
# Processing Record 25 of Set 8 | mandera
# Processing Record 26 of Set 8 | san patricio
# Processing Record 27 of Set 8 | kuznechnoye
# Processing Record 28 of Set 8 | charters towers
# Processing Record 29 of Set 8 | kjollefjord
# Processing Record 30 of Set 8 | half moon bay
# Processing Record 31 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 8 | tateyama
# Processing Record 33 of Set 8 | adrar
# Processing Record 34 of Set 8 | ler
# Processing Record 35 of Set 8 | mao
# Processing Record 36 of Set 8 | cabedelo
# Processing Record 37 of Set 8 | derzhavinsk
# Processing Record 38 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 8 | tabou
# Processing Record 40 of Set 8 | bilma
# Processing Record 41 of Set 8 | loiza
# Processing Record 42 of Set 8 | nchelenge
# Processing Record 43 of Set 8 | ewo
# Processing Record 44 of Set 8 | kaili
# Processing Record 45 of Set 8 | xuddur
# Processing Record 46 of Set 8 | kasungu
# Processing Record 47 of Set 8 | floriano
# Processing Record 48 of Set 8 | los llanos de aridane
# Processing Record 49 of Set 8 | kaeo
# Processing Record 50 of Set 8 | sovetskiy
# Processing Record 1 of Set 9 | mumford
# Processing Record 2 of Set 9 | copacabana
# Processing Record 3 of Set 9 | matay
# Processing Record 4 of Set 9 | timra
# Processing Record 5 of Set 9 | vilhena
# Processing Record 6 of Set 9 | kodiak
# Processing Record 7 of Set 9 | alpena
# Processing Record 8 of Set 9 | odweyne
# Processing Record 9 of Set 9 | narsaq
# Processing Record 10 of Set 9 | westport
# Processing Record 11 of Set 9 | buala
# Processing Record 12 of Set 9 | hobyo
# Processing Record 13 of Set 9 | yorosso
# Processing Record 14 of Set 9 | lardos
# Processing Record 15 of Set 9 | vilyuysk
# Processing Record 16 of Set 9 | palembang
# Processing Record 17 of Set 9 | marsh harbour
# Processing Record 18 of Set 9 | shchelyayur
# City not found. Skipping...
# Processing Record 19 of Set 9 | palu
# Processing Record 20 of Set 9 | la romana
# Processing Record 21 of Set 9 | neudorfl
# Processing Record 22 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 23 of Set 9 | aberystwyth
# Processing Record 24 of Set 9 | launceston
# Processing Record 25 of Set 9 | shitanjing
# Processing Record 26 of Set 9 | aranos
# Processing Record 27 of Set 9 | nunoa
# Processing Record 28 of Set 9 | naftah
# City not found. Skipping...
# Processing Record 29 of Set 9 | magadan
# Processing Record 30 of Set 9 | namtsy
# Processing Record 31 of Set 9 | henties bay
# Processing Record 32 of Set 9 | kavaratti
# Processing Record 33 of Set 9 | umba
# Processing Record 34 of Set 9 | alofi
# Processing Record 35 of Set 9 | mwene-ditu
# Processing Record 36 of Set 9 | termiz
# Processing Record 37 of Set 9 | northam
# Processing Record 38 of Set 9 | inirida
# Processing Record 39 of Set 9 | kankon
# Processing Record 40 of Set 9 | fukue
# Processing Record 41 of Set 9 | georgetown
# Processing Record 42 of Set 9 | hajduboszormeny
# Processing Record 43 of Set 9 | kuruksay
# City not found. Skipping...
# Processing Record 44 of Set 9 | xinzhi
# Processing Record 45 of Set 9 | svobodnyy
# Processing Record 46 of Set 9 | sanmenxia
# Processing Record 47 of Set 9 | kilimatinde
# Processing Record 48 of Set 9 | ingolstadt
# Processing Record 49 of Set 9 | mahon
# Processing Record 50 of Set 9 | nanyuki
# Processing Record 1 of Set 10 | vestmannaeyjar
# Processing Record 2 of Set 10 | arman
# Processing Record 3 of Set 10 | taman
# Processing Record 4 of Set 10 | severo-kurilsk
# Processing Record 5 of Set 10 | waipawa
# Processing Record 6 of Set 10 | sorland
# Processing Record 7 of Set 10 | moranbah
# Processing Record 8 of Set 10 | mahuva
# Processing Record 9 of Set 10 | taoudenni
# Processing Record 10 of Set 10 | manzanillo
# Processing Record 11 of Set 10 | birin
# Processing Record 12 of Set 10 | pangody
# Processing Record 13 of Set 10 | kayerkan
# Processing Record 14 of Set 10 | novoagansk
# Processing Record 15 of Set 10 | gushikawa
# Processing Record 16 of Set 10 | pao de acucar
# Processing Record 17 of Set 10 | plover
# Processing Record 18 of Set 10 | belmonte
# Processing Record 19 of Set 10 | cowra
# Processing Record 20 of Set 10 | hammerfest
# Processing Record 21 of Set 10 | soma
# Processing Record 22 of Set 10 | tessalit
# Processing Record 23 of Set 10 | palmeira das missoes
# Processing Record 24 of Set 10 | ucluelet
# Processing Record 25 of Set 10 | san quintin
# Processing Record 26 of Set 10 | togur
# Processing Record 27 of Set 10 | lebanon
# Processing Record 28 of Set 10 | yumbe
# Processing Record 29 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 30 of Set 10 | kidal
# Processing Record 31 of Set 10 | lushunkou
# City not found. Skipping...
# Processing Record 32 of Set 10 | verkhnetulomskiy
# Processing Record 33 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 10 | valledupar
# Processing Record 35 of Set 10 | nizhniy baskunchak
# Processing Record 36 of Set 10 | yerbogachen
# Processing Record 37 of Set 10 | ust-kuyga
# Processing Record 38 of Set 10 | shakiso
# Processing Record 39 of Set 10 | road town
# Processing Record 40 of Set 10 | mzimba
# Processing Record 41 of Set 10 | port hardy
# Processing Record 42 of Set 10 | ikungi
# Processing Record 43 of Set 10 | pop
# Processing Record 44 of Set 10 | itaborai
# Processing Record 45 of Set 10 | fuzhou
# Processing Record 46 of Set 10 | ughelli
# Processing Record 47 of Set 10 | wanxian
# Processing Record 48 of Set 10 | mitsamiouli
# Processing Record 49 of Set 10 | muriwai beach
# Processing Record 50 of Set 10 | lamballe
# Processing Record 1 of Set 11 | coos bay
# Processing Record 2 of Set 11 | cidreira
# Processing Record 3 of Set 11 | paita
# Processing Record 4 of Set 11 | jining
# Processing Record 5 of Set 11 | horki
# Processing Record 6 of Set 11 | dhidhdhoo
# Processing Record 7 of Set 11 | fortuna
# Processing Record 8 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 9 of Set 11 | nago
# Processing Record 10 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 11 | silver city
# Processing Record 12 of Set 11 | port-de-paix
# City not found. Skipping...
# Processing Record 13 of Set 11 | nsanje
# Processing Record 14 of Set 11 | lazaro cardenas
# Processing Record 15 of Set 11 | baiquan
# Processing Record 16 of Set 11 | vicuna
# Processing Record 17 of Set 11 | plaster rock
# Processing Record 18 of Set 11 | takoradi
# Processing Record 19 of Set 11 | bereda
# Processing Record 20 of Set 11 | yakeshi
# Processing Record 21 of Set 11 | padang
# Processing Record 22 of Set 11 | chingola
# Processing Record 23 of Set 11 | ornskoldsvik
# Processing Record 24 of Set 11 | talcahuano
# Processing Record 25 of Set 11 | tongliao
# Processing Record 26 of Set 11 | lagos
# Processing Record 27 of Set 11 | bawku
# Processing Record 28 of Set 11 | marquette
# Processing Record 29 of Set 11 | sitka
# Processing Record 30 of Set 11 | kailua
# Processing Record 31 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 32 of Set 11 | asyut
# Processing Record 33 of Set 11 | sharjah
# Processing Record 34 of Set 11 | razole
# Processing Record 35 of Set 11 | chernyshevskiy
# Processing Record 36 of Set 11 | manjeshwar
# Processing Record 37 of Set 11 | sri aman
# Processing Record 38 of Set 11 | araouane
# Processing Record 39 of Set 11 | kokopo
# Processing Record 40 of Set 11 | talnakh
# Processing Record 41 of Set 11 | arcachon
# Processing Record 42 of Set 11 | harrison
# Processing Record 43 of Set 11 | manohar thana
# Processing Record 44 of Set 11 | karachi
# Processing Record 45 of Set 11 | qinhuangdao
# Processing Record 46 of Set 11 | ponazyrevo
# Processing Record 47 of Set 11 | mansehra
# Processing Record 48 of Set 11 | tabas
# Processing Record 49 of Set 11 | burnie
# Processing Record 50 of Set 11 | teya
# Processing Record 1 of Set 12 | am timan
# Processing Record 2 of Set 12 | oktyabrskoye
# Processing Record 3 of Set 12 | coffs harbour
# Processing Record 4 of Set 12 | puri
# Processing Record 5 of Set 12 | kati
# Processing Record 6 of Set 12 | vila franca do campo
# Processing Record 7 of Set 12 | galgani
# City not found. Skipping...
# Processing Record 8 of Set 12 | angoche
# Processing Record 9 of Set 12 | saint-francois
# Processing Record 10 of Set 12 | wuan
# Processing Record 11 of Set 12 | solnechnyy
# Processing Record 12 of Set 12 | kurilsk
# Processing Record 13 of Set 12 | cozumel
# Processing Record 14 of Set 12 | yelizovo
# Processing Record 15 of Set 12 | rovnoye
# Processing Record 16 of Set 12 | chimbarongo
# Processing Record 17 of Set 12 | tadepallegudem
# Processing Record 18 of Set 12 | guardiagrele
# Processing Record 19 of Set 12 | correntina
# Processing Record 20 of Set 12 | belaya gora
# Processing Record 21 of Set 12 | aripuana
# Processing Record 22 of Set 12 | diamantino
# Processing Record 23 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 24 of Set 12 | gogrial
# Processing Record 25 of Set 12 | richards bay
# Processing Record 26 of Set 12 | olafsvik
# Processing Record 27 of Set 12 | ulagan
# Processing Record 28 of Set 12 | matoury
# Processing Record 29 of Set 12 | marolambo
# Processing Record 30 of Set 12 | nueva gorgona
# Processing Record 31 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 32 of Set 12 | sur
# Processing Record 33 of Set 12 | lokomotivnyy
# Processing Record 34 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 35 of Set 12 | foz
# Processing Record 36 of Set 12 | ntoum
# Processing Record 37 of Set 12 | saint-georges
# Processing Record 38 of Set 12 | papa
# Processing Record 39 of Set 12 | luanda
# Processing Record 40 of Set 12 | esmeraldas
# Processing Record 41 of Set 12 | khangarh
# Processing Record 42 of Set 12 | moroni
# Processing Record 43 of Set 12 | imbituba
# Processing Record 44 of Set 12 | hoquiam
# Processing Record 45 of Set 12 | katsuura
# Processing Record 46 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 47 of Set 12 | paucartambo
# City not found. Skipping...
# Processing Record 48 of Set 12 | baturaja
# Processing Record 49 of Set 12 | khilok
# Processing Record 50 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 1 of Set 13 | havre-saint-pierre
# Processing Record 2 of Set 13 | jumla
# Processing Record 3 of Set 13 | okha
# Processing Record 4 of Set 13 | gumdag
# Processing Record 5 of Set 13 | caravelas
# Processing Record 6 of Set 13 | ojinaga
# Processing Record 7 of Set 13 | lakes entrance
# Processing Record 8 of Set 13 | berlevag
# Processing Record 9 of Set 13 | flinders
# Processing Record 10 of Set 13 | bandundu
# Processing Record 11 of Set 13 | eydhafushi
# Processing Record 12 of Set 13 | nipawin
# Processing Record 13 of Set 13 | chirongui
# Processing Record 14 of Set 13 | gulabpura
# Processing Record 15 of Set 13 | zhangye
# Processing Record 16 of Set 13 | ruwi
# Processing Record 17 of Set 13 | hualmay
# Processing Record 18 of Set 13 | porto de moz
# Processing Record 19 of Set 13 | lehigh acres
# Processing Record 20 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 21 of Set 13 | arroyo
# Processing Record 22 of Set 13 | bryan
# Processing Record 23 of Set 13 | neiafu
# Processing Record 24 of Set 13 | ngunguru
# Processing Record 25 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 26 of Set 13 | dunedin
# Processing Record 27 of Set 13 | pimentel
# Processing Record 28 of Set 13 | katherine
# Processing Record 29 of Set 13 | beroroha
# Processing Record 30 of Set 13 | okhotsk
# Processing Record 31 of Set 13 | lasa
# Processing Record 32 of Set 13 | bjornevatn
# Processing Record 33 of Set 13 | sibolga
# Processing Record 34 of Set 13 | kiruna
# Processing Record 35 of Set 13 | cabo san lucas
# Processing Record 36 of Set 13 | haines junction
# Processing Record 37 of Set 13 | murgab
# Processing Record 38 of Set 13 | lakatoro
# Processing Record 39 of Set 13 | godda
# Processing Record 40 of Set 13 | pietrosani
# Processing Record 41 of Set 13 | katha
# City not found. Skipping...
# Processing Record 42 of Set 13 | tiksi
# Processing Record 43 of Set 13 | yokadouma
# Processing Record 44 of Set 13 | nyimba
# Processing Record 45 of Set 13 | tungor
# Processing Record 46 of Set 13 | smithers
# Processing Record 47 of Set 13 | sihora
# Processing Record 48 of Set 13 | boyuibe
# Processing Record 49 of Set 13 | porangatu
# Processing Record 50 of Set 13 | montrose
# Processing Record 1 of Set 14 | cap malheureux
# Processing Record 2 of Set 14 | mujiayingzi
# Processing Record 3 of Set 14 | dingle
# Processing Record 4 of Set 14 | santa cruz
# Processing Record 5 of Set 14 | gweru
# Processing Record 6 of Set 14 | guarda
# Processing Record 7 of Set 14 | ijaki
# City not found. Skipping...
# Processing Record 8 of Set 14 | port pirie
# Processing Record 9 of Set 14 | white center
# Processing Record 10 of Set 14 | ossora
# Processing Record 11 of Set 14 | batemans bay
# Processing Record 12 of Set 14 | ivanava
# Processing Record 13 of Set 14 | barabai
# Processing Record 14 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 14 | kuytun
# Processing Record 16 of Set 14 | frontera
# Processing Record 17 of Set 14 | keningau
# Processing Record 18 of Set 14 | pundaguitan
# Processing Record 19 of Set 14 | krasnaya gorka
# Processing Record 20 of Set 14 | maumere
# Processing Record 21 of Set 14 | pochutla
# Processing Record 22 of Set 14 | barabinsk
# Processing Record 23 of Set 14 | shahreza
# Processing Record 24 of Set 14 | ordu
# Processing Record 25 of Set 14 | rio branco
# Processing Record 26 of Set 14 | bellefontaine
# Processing Record 27 of Set 14 | calabozo
# Processing Record 28 of Set 14 | zhezkazgan
# Processing Record 29 of Set 14 | tautira
# Processing Record 30 of Set 14 | gimli
# Processing Record 31 of Set 14 | khor
# Processing Record 32 of Set 14 | daru
# Processing Record 33 of Set 14 | mozarlandia
# Processing Record 34 of Set 14 | sisimiut
# Processing Record 35 of Set 14 | bonavista
# Processing Record 36 of Set 14 | carutapera
# Processing Record 37 of Set 14 | santa rosa
# Processing Record 38 of Set 14 | synya
# Processing Record 39 of Set 14 | kriva palanka
# Processing Record 40 of Set 14 | aukra
# Processing Record 41 of Set 14 | kyabe
# Processing Record 42 of Set 14 | talaya
# Processing Record 43 of Set 14 | havelock
# Processing Record 44 of Set 14 | capao bonito
# Processing Record 45 of Set 14 | roald
# Processing Record 46 of Set 14 | yerkoy
# Processing Record 47 of Set 14 | loudeac
# Processing Record 48 of Set 14 | vila do maio
# Processing Record 49 of Set 14 | gazojak
# Processing Record 50 of Set 14 | bud
# Processing Record 1 of Set 15 | kandiari
# Processing Record 2 of Set 15 | ciudad bolivar
# Processing Record 3 of Set 15 | guerrero negro
# Processing Record 4 of Set 15 | siguiri
# Processing Record 5 of Set 15 | katangli
# Processing Record 6 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 7 of Set 15 | washington
# Processing Record 8 of Set 15 | khandyga
# Processing Record 9 of Set 15 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 15 | new braunfels
# Processing Record 11 of Set 15 | bowen
# Processing Record 12 of Set 15 | saint-augustin
# Processing Record 13 of Set 15 | jackson
# Processing Record 14 of Set 15 | puerto colombia
# Processing Record 15 of Set 15 | zlatoustovsk
# City not found. Skipping...
# Processing Record 16 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 17 of Set 15 | castelo branco
# Processing Record 18 of Set 15 | mariental
# Processing Record 19 of Set 15 | kinablangan
# Processing Record 20 of Set 15 | haimen
# Processing Record 21 of Set 15 | vardo
# Processing Record 22 of Set 15 | sarangani
# Processing Record 23 of Set 15 | nanning
# Processing Record 24 of Set 15 | remedios
# Processing Record 25 of Set 15 | natchez
# Processing Record 26 of Set 15 | namibe
# Processing Record 27 of Set 15 | kovdor
# Processing Record 28 of Set 15 | lewistown
# Processing Record 29 of Set 15 | tsumeb
# Processing Record 30 of Set 15 | taywarah
# Processing Record 31 of Set 15 | rafai
# Processing Record 32 of Set 15 | christchurch
# Processing Record 33 of Set 15 | khomeyn
# Processing Record 34 of Set 15 | siva
# Processing Record 35 of Set 15 | alexandria
# Processing Record 36 of Set 15 | bhilwara
# Processing Record 37 of Set 15 | ourossogui
# Processing Record 38 of Set 15 | teguldet
# Processing Record 39 of Set 15 | sinegorye
# Processing Record 40 of Set 15 | north bend
# Processing Record 41 of Set 15 | kupang
# Processing Record 42 of Set 15 | socorro
# Processing Record 43 of Set 15 | tadine
# Processing Record 44 of Set 15 | horta
# Processing Record 45 of Set 15 | buariki
# City not found. Skipping...
# Processing Record 46 of Set 15 | tigzirt
# Processing Record 47 of Set 15 | maldonado
# Processing Record 48 of Set 15 | vredendal
# Processing Record 49 of Set 15 | trairi
# Processing Record 50 of Set 15 | grand gaube
# Processing Record 1 of Set 16 | darhan
# Processing Record 2 of Set 16 | khakhea
# Processing Record 3 of Set 16 | campeche
# Processing Record 4 of Set 16 | kysyl-syr
# Processing Record 5 of Set 16 | edd
# Processing Record 6 of Set 16 | skagastrond
# City not found. Skipping...
# Processing Record 7 of Set 16 | chapada dos guimaraes
# Processing Record 8 of Set 16 | abu kamal
# Processing Record 9 of Set 16 | canutama
# Processing Record 10 of Set 16 | ambad
# Processing Record 11 of Set 16 | betanzos
# Processing Record 12 of Set 16 | dicabisagan
# Processing Record 13 of Set 16 | kushima
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Recall that we can convert a list of dictionaries to a Pandas DataFrame using df = pd.DataFrame(list with dictionaries).
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Castro      BR -24.7911  -50.0119     49.14        81          28
# 1  Port Elizabeth      ZA -33.9180   25.5701     53.89        87           0
# 2     Provideniya      RU  64.3833 -173.3000     51.91        58           0
# 3        Hamilton      US  39.1834  -84.5333     67.05        66         100
# 4       Hithadhoo      MV  -0.6000   73.0833     83.77        71          98
# 5      Agua Verde      MX  22.9000 -106.0500     79.07        64           3
# 6          Atuona      PF  -9.8000 -139.0333     77.92        79          28
# 7       Busselton      AU -33.6500  115.3333     60.91        71          84
# 8       Maniitsoq      GL  65.4167  -52.9000     32.18        97         100
# 9         Ternate      ID   0.8000  127.4000     81.25        78          99
#
#    Wind Speed Current Description
# 0        2.57    scattered clouds
# 1        3.44           clear sky
# 2       15.99           clear sky
# 3       17.27     overcast clouds
# 4       13.20     overcast clouds
# 5        9.69           clear sky
# 6       17.74          light rain
# 7       20.69       broken clouds
# 8       30.91                snow
# 9        3.40     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
