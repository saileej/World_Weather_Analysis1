# %%
import numpy as np
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
# The citipy module finds the nearest city to the latitude and longitude pair with a population of 500 or more.
from citipy import citipy

# %%
# # Use the tuple() function to display the latitude and longitude combinations.
# for coordinate in coordinates:
#     print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
#           citipy.nearest_city(coordinate[0], coordinate[1]).country_code)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 608

# %%
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#loop through cities in list
for i, city in enumerate(cities):
    
    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #create URL endpoint for city
    city_url = url + '&q=' + city.replace(" ","+")
    
    #log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # add 1 to record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saskylakh
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | pietarsaari
# Processing Record 4 of Set 1 | avarua
# Processing Record 5 of Set 1 | hithadhoo
# Processing Record 6 of Set 1 | barrow
# Processing Record 7 of Set 1 | carnarvon
# Processing Record 8 of Set 1 | freeport
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | cayenne
# Processing Record 11 of Set 1 | camabatela
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | coihueco
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | pevek
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | sencur
# Processing Record 19 of Set 1 | yellowknife
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | atikokan
# Processing Record 22 of Set 1 | bambous virieux
# Processing Record 23 of Set 1 | sulangan
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | castro
# Processing Record 26 of Set 1 | salaga
# Processing Record 27 of Set 1 | williams lake
# Processing Record 28 of Set 1 | kruisfontein
# Processing Record 29 of Set 1 | tual
# Processing Record 30 of Set 1 | khatanga
# Processing Record 31 of Set 1 | sitka
# Processing Record 32 of Set 1 | iquitos
# Processing Record 33 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 1 | qasigiannguit
# Processing Record 35 of Set 1 | tilichiki
# Processing Record 36 of Set 1 | ridgecrest
# Processing Record 37 of Set 1 | ostrovnoy
# Processing Record 38 of Set 1 | mataura
# Processing Record 39 of Set 1 | umm kaddadah
# Processing Record 40 of Set 1 | port alfred
# Processing Record 41 of Set 1 | mahebourg
# Processing Record 42 of Set 1 | lavrentiya
# Processing Record 43 of Set 1 | leh
# Processing Record 44 of Set 1 | juegang
# Processing Record 45 of Set 1 | lingyuan
# Processing Record 46 of Set 1 | msanga
# Processing Record 47 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 1 | paamiut
# Processing Record 49 of Set 1 | temaraia
# City not found. Skipping...
# Processing Record 50 of Set 1 | zonguldak
# Processing Record 1 of Set 2 | severo-kurilsk
# Processing Record 2 of Set 2 | phu ly
# Processing Record 3 of Set 2 | muros
# Processing Record 4 of Set 2 | hilo
# Processing Record 5 of Set 2 | atuona
# Processing Record 6 of Set 2 | faanui
# Processing Record 7 of Set 2 | tasiilaq
# Processing Record 8 of Set 2 | dingle
# Processing Record 9 of Set 2 | yulara
# Processing Record 10 of Set 2 | kaeo
# Processing Record 11 of Set 2 | shorapani
# Processing Record 12 of Set 2 | carahue
# Processing Record 13 of Set 2 | yinchuan
# Processing Record 14 of Set 2 | puerto ayora
# Processing Record 15 of Set 2 | leshukonskoye
# Processing Record 16 of Set 2 | kapaa
# Processing Record 17 of Set 2 | broome
# Processing Record 18 of Set 2 | tuktoyaktuk
# Processing Record 19 of Set 2 | upernavik
# Processing Record 20 of Set 2 | qaanaaq
# Processing Record 21 of Set 2 | palu
# Processing Record 22 of Set 2 | goderich
# Processing Record 23 of Set 2 | saldanha
# Processing Record 24 of Set 2 | hobart
# Processing Record 25 of Set 2 | arraial do cabo
# Processing Record 26 of Set 2 | sangar
# Processing Record 27 of Set 2 | ponta do sol
# Processing Record 28 of Set 2 | georgetown
# Processing Record 29 of Set 2 | nikolskoye
# Processing Record 30 of Set 2 | hamilton
# Processing Record 31 of Set 2 | salalah
# Processing Record 32 of Set 2 | ribeira grande
# Processing Record 33 of Set 2 | narasannapeta
# Processing Record 34 of Set 2 | nouadhibou
# Processing Record 35 of Set 2 | ruteng
# Processing Record 36 of Set 2 | lebu
# Processing Record 37 of Set 2 | dikson
# Processing Record 38 of Set 2 | cherskiy
# Processing Record 39 of Set 2 | oriximina
# Processing Record 40 of Set 2 | lorengau
# Processing Record 41 of Set 2 | torbay
# Processing Record 42 of Set 2 | tuatapere
# Processing Record 43 of Set 2 | challapata
# Processing Record 44 of Set 2 | saint-marc
# Processing Record 45 of Set 2 | bardiyah
# Processing Record 46 of Set 2 | saint anthony
# Processing Record 47 of Set 2 | san quintin
# Processing Record 48 of Set 2 | chuy
# Processing Record 49 of Set 2 | ambilobe
# Processing Record 50 of Set 2 | dagata
# City not found. Skipping...
# Processing Record 1 of Set 3 | saint-augustin
# Processing Record 2 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 3 | kaputa
# Processing Record 4 of Set 3 | ardatov
# Processing Record 5 of Set 3 | dolbeau
# City not found. Skipping...
# Processing Record 6 of Set 3 | kodiak
# Processing Record 7 of Set 3 | harnosand
# Processing Record 8 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 3 | jamestown
# Processing Record 10 of Set 3 | mitchell
# Processing Record 11 of Set 3 | verkhoyansk
# Processing Record 12 of Set 3 | sorland
# Processing Record 13 of Set 3 | forbes
# Processing Record 14 of Set 3 | artyk
# City not found. Skipping...
# Processing Record 15 of Set 3 | kosh-agach
# Processing Record 16 of Set 3 | raga
# Processing Record 17 of Set 3 | key west
# Processing Record 18 of Set 3 | padang
# Processing Record 19 of Set 3 | coihaique
# Processing Record 20 of Set 3 | flinders
# Processing Record 21 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 3 | sohag
# Processing Record 23 of Set 3 | kaitangata
# Processing Record 24 of Set 3 | hervey bay
# Processing Record 25 of Set 3 | iqaluit
# Processing Record 26 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 3 | jabiru
# City not found. Skipping...
# Processing Record 28 of Set 3 | taoudenni
# Processing Record 29 of Set 3 | longyearbyen
# Processing Record 30 of Set 3 | haines junction
# Processing Record 31 of Set 3 | vaitape
# Processing Record 32 of Set 3 | suzhou
# Processing Record 33 of Set 3 | kempsey
# Processing Record 34 of Set 3 | wanning
# Processing Record 35 of Set 3 | new norfolk
# Processing Record 36 of Set 3 | te anau
# Processing Record 37 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 3 | nortelandia
# Processing Record 39 of Set 3 | nanortalik
# Processing Record 40 of Set 3 | victoria
# Processing Record 41 of Set 3 | ketchikan
# Processing Record 42 of Set 3 | nesbyen
# Processing Record 43 of Set 3 | lompoc
# Processing Record 44 of Set 3 | sakakah
# Processing Record 45 of Set 3 | vaini
# Processing Record 46 of Set 3 | ancud
# Processing Record 47 of Set 3 | narsaq
# Processing Record 48 of Set 3 | ulaanbaatar
# Processing Record 49 of Set 3 | villa maria
# Processing Record 50 of Set 3 | ola
# Processing Record 1 of Set 4 | jeffersonville
# Processing Record 2 of Set 4 | russell
# Processing Record 3 of Set 4 | bredasdorp
# Processing Record 4 of Set 4 | guaymas
# Processing Record 5 of Set 4 | grand gaube
# Processing Record 6 of Set 4 | san cristobal
# Processing Record 7 of Set 4 | thinadhoo
# Processing Record 8 of Set 4 | hasaki
# Processing Record 9 of Set 4 | raudeberg
# Processing Record 10 of Set 4 | alofi
# Processing Record 11 of Set 4 | batagay-alyta
# Processing Record 12 of Set 4 | islampur
# Processing Record 13 of Set 4 | olinda
# Processing Record 14 of Set 4 | saint-pierre
# Processing Record 15 of Set 4 | sistranda
# Processing Record 16 of Set 4 | norman wells
# Processing Record 17 of Set 4 | vardo
# Processing Record 18 of Set 4 | nicoya
# Processing Record 19 of Set 4 | ilulissat
# Processing Record 20 of Set 4 | shiogama
# Processing Record 21 of Set 4 | loukhi
# Processing Record 22 of Set 4 | straumen
# Processing Record 23 of Set 4 | novospasskoye
# Processing Record 24 of Set 4 | thompson
# Processing Record 25 of Set 4 | canete
# Processing Record 26 of Set 4 | chapais
# Processing Record 27 of Set 4 | shahganj
# Processing Record 28 of Set 4 | fort nelson
# Processing Record 29 of Set 4 | tuggurt
# City not found. Skipping...
# Processing Record 30 of Set 4 | waipawa
# Processing Record 31 of Set 4 | upata
# Processing Record 32 of Set 4 | road town
# Processing Record 33 of Set 4 | hambantota
# Processing Record 34 of Set 4 | la seyne-sur-mer
# Processing Record 35 of Set 4 | dondo
# Processing Record 36 of Set 4 | bom jesus
# Processing Record 37 of Set 4 | constitucion
# Processing Record 38 of Set 4 | aklavik
# Processing Record 39 of Set 4 | neiafu
# Processing Record 40 of Set 4 | mar del plata
# Processing Record 41 of Set 4 | lasa
# Processing Record 42 of Set 4 | saint stephen
# Processing Record 43 of Set 4 | dolores
# Processing Record 44 of Set 4 | perevolotskiy
# Processing Record 45 of Set 4 | makakilo city
# Processing Record 46 of Set 4 | sydney
# Processing Record 47 of Set 4 | butaritari
# Processing Record 48 of Set 4 | tiznit
# Processing Record 49 of Set 4 | provideniya
# Processing Record 50 of Set 4 | guerrero negro
# Processing Record 1 of Set 5 | bhan
# Processing Record 2 of Set 5 | taltal
# Processing Record 3 of Set 5 | marawi
# Processing Record 4 of Set 5 | mount gambier
# Processing Record 5 of Set 5 | kenai
# Processing Record 6 of Set 5 | mildura
# Processing Record 7 of Set 5 | tiksi
# Processing Record 8 of Set 5 | mogadishu
# Processing Record 9 of Set 5 | vitim
# Processing Record 10 of Set 5 | yumen
# Processing Record 11 of Set 5 | portland
# Processing Record 12 of Set 5 | saint-philippe
# Processing Record 13 of Set 5 | buala
# Processing Record 14 of Set 5 | kloulklubed
# Processing Record 15 of Set 5 | port lincoln
# Processing Record 16 of Set 5 | bubaque
# Processing Record 17 of Set 5 | nizhniy odes
# Processing Record 18 of Set 5 | shingu
# Processing Record 19 of Set 5 | am timan
# Processing Record 20 of Set 5 | sipe sipe
# Processing Record 21 of Set 5 | callaway
# Processing Record 22 of Set 5 | nsanje
# Processing Record 23 of Set 5 | yatou
# Processing Record 24 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 5 | odweyne
# Processing Record 26 of Set 5 | ternate
# Processing Record 27 of Set 5 | kutum
# Processing Record 28 of Set 5 | sambava
# Processing Record 29 of Set 5 | mount isa
# Processing Record 30 of Set 5 | salta
# Processing Record 31 of Set 5 | san patricio
# Processing Record 32 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 33 of Set 5 | myitkyina
# Processing Record 34 of Set 5 | venado tuerto
# Processing Record 35 of Set 5 | aksu
# Processing Record 36 of Set 5 | gat
# Processing Record 37 of Set 5 | almeirim
# Processing Record 38 of Set 5 | kaduna
# Processing Record 39 of Set 5 | saint george
# Processing Record 40 of Set 5 | asayita
# City not found. Skipping...
# Processing Record 41 of Set 5 | faya
# Processing Record 42 of Set 5 | primo tapia
# Processing Record 43 of Set 5 | roebourne
# Processing Record 44 of Set 5 | mezen
# Processing Record 45 of Set 5 | wahran
# City not found. Skipping...
# Processing Record 46 of Set 5 | tutoia
# Processing Record 47 of Set 5 | khuldabad
# Processing Record 48 of Set 5 | grindavik
# Processing Record 49 of Set 5 | mansehra
# Processing Record 50 of Set 5 | grand-santi
# Processing Record 1 of Set 6 | genhe
# Processing Record 2 of Set 6 | ndele
# Processing Record 3 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 6 | slave lake
# Processing Record 5 of Set 6 | kaset sombun
# Processing Record 6 of Set 6 | panjab
# Processing Record 7 of Set 6 | hibbing
# Processing Record 8 of Set 6 | luwuk
# Processing Record 9 of Set 6 | manavgat
# Processing Record 10 of Set 6 | altay
# Processing Record 11 of Set 6 | lembeni
# Processing Record 12 of Set 6 | dombarovskiy
# Processing Record 13 of Set 6 | bonoua
# Processing Record 14 of Set 6 | bethel
# Processing Record 15 of Set 6 | treinta y tres
# Processing Record 16 of Set 6 | chake chake
# Processing Record 17 of Set 6 | vanimo
# Processing Record 18 of Set 6 | mana
# Processing Record 19 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 6 | katangli
# Processing Record 21 of Set 6 | inirida
# Processing Record 22 of Set 6 | clyde river
# Processing Record 23 of Set 6 | puerto escondido
# Processing Record 24 of Set 6 | dibaya
# City not found. Skipping...
# Processing Record 25 of Set 6 | edelira
# Processing Record 26 of Set 6 | narrabri
# Processing Record 27 of Set 6 | valkeala
# Processing Record 28 of Set 6 | cidreira
# Processing Record 29 of Set 6 | saint-francois
# Processing Record 30 of Set 6 | esperance
# Processing Record 31 of Set 6 | carballo
# Processing Record 32 of Set 6 | okhotsk
# Processing Record 33 of Set 6 | aktash
# Processing Record 34 of Set 6 | lata
# Processing Record 35 of Set 6 | navrongo
# Processing Record 36 of Set 6 | chokurdakh
# Processing Record 37 of Set 6 | la asuncion
# Processing Record 38 of Set 6 | kamaishi
# Processing Record 39 of Set 6 | nanakuli
# Processing Record 40 of Set 6 | luanda
# Processing Record 41 of Set 6 | husavik
# Processing Record 42 of Set 6 | wasilla
# Processing Record 43 of Set 6 | olkhovka
# Processing Record 44 of Set 6 | pathein
# Processing Record 45 of Set 6 | antalaha
# Processing Record 46 of Set 6 | gurlan
# Processing Record 47 of Set 6 | mouzakion
# City not found. Skipping...
# Processing Record 48 of Set 6 | high level
# Processing Record 49 of Set 6 | isangel
# Processing Record 50 of Set 6 | embonas
# Processing Record 1 of Set 7 | dalvik
# Processing Record 2 of Set 7 | nizwa
# Processing Record 3 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 7 | loreto
# Processing Record 5 of Set 7 | vershino-darasunskiy
# Processing Record 6 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 7 of Set 7 | kalininsk
# Processing Record 8 of Set 7 | zhezkazgan
# Processing Record 9 of Set 7 | airai
# Processing Record 10 of Set 7 | montepuez
# Processing Record 11 of Set 7 | kingaroy
# Processing Record 12 of Set 7 | cockburn town
# Processing Record 13 of Set 7 | nome
# Processing Record 14 of Set 7 | cabo san lucas
# Processing Record 15 of Set 7 | bengkulu
# Processing Record 16 of Set 7 | comodoro rivadavia
# Processing Record 17 of Set 7 | barpeta
# Processing Record 18 of Set 7 | skotterud
# Processing Record 19 of Set 7 | krasnokamensk
# Processing Record 20 of Set 7 | matane
# Processing Record 21 of Set 7 | makaleng
# Processing Record 22 of Set 7 | riyadh
# Processing Record 23 of Set 7 | havre
# Processing Record 24 of Set 7 | sabang
# Processing Record 25 of Set 7 | iwanai
# Processing Record 26 of Set 7 | nelson bay
# Processing Record 27 of Set 7 | poum
# Processing Record 28 of Set 7 | baiyin
# Processing Record 29 of Set 7 | mayumba
# Processing Record 30 of Set 7 | asfi
# Processing Record 31 of Set 7 | barra dos coqueiros
# Processing Record 32 of Set 7 | college
# Processing Record 33 of Set 7 | aligarh
# Processing Record 34 of Set 7 | pacifica
# Processing Record 35 of Set 7 | beloha
# Processing Record 36 of Set 7 | general roca
# Processing Record 37 of Set 7 | eyl
# Processing Record 38 of Set 7 | kismayo
# Processing Record 39 of Set 7 | luderitz
# Processing Record 40 of Set 7 | penzance
# Processing Record 41 of Set 7 | bintulu
# Processing Record 42 of Set 7 | monte patria
# Processing Record 43 of Set 7 | hurghada
# Processing Record 44 of Set 7 | karratha
# Processing Record 45 of Set 7 | armidale
# Processing Record 46 of Set 7 | codrington
# Processing Record 47 of Set 7 | healdsburg
# Processing Record 48 of Set 7 | noshiro
# Processing Record 49 of Set 7 | kahului
# Processing Record 50 of Set 7 | khormuj
# City not found. Skipping...
# Processing Record 1 of Set 8 | halifax
# Processing Record 2 of Set 8 | tottori
# Processing Record 3 of Set 8 | kalakamati
# Processing Record 4 of Set 8 | dwarka
# Processing Record 5 of Set 8 | gombong
# Processing Record 6 of Set 8 | saint-denis
# Processing Record 7 of Set 8 | chardara
# Processing Record 8 of Set 8 | rock sound
# Processing Record 9 of Set 8 | claremore
# Processing Record 10 of Set 8 | mae sai
# Processing Record 11 of Set 8 | dubna
# Processing Record 12 of Set 8 | vila velha
# Processing Record 13 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 14 of Set 8 | esil
# Processing Record 15 of Set 8 | marsh harbour
# Processing Record 16 of Set 8 | norsup
# Processing Record 17 of Set 8 | goma
# Processing Record 18 of Set 8 | dalian
# Processing Record 19 of Set 8 | porto novo
# Processing Record 20 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 8 | mugur-aksy
# Processing Record 22 of Set 8 | ijaki
# City not found. Skipping...
# Processing Record 23 of Set 8 | kauhajoki
# Processing Record 24 of Set 8 | erken-shakhar
# City not found. Skipping...
# Processing Record 25 of Set 8 | coquimbo
# Processing Record 26 of Set 8 | mayo
# Processing Record 27 of Set 8 | manono
# Processing Record 28 of Set 8 | flin flon
# Processing Record 29 of Set 8 | orotukan
# Processing Record 30 of Set 8 | lhokseumawe
# Processing Record 31 of Set 8 | ramon
# Processing Record 32 of Set 8 | visby
# Processing Record 33 of Set 8 | baykit
# Processing Record 34 of Set 8 | safaga
# Processing Record 35 of Set 8 | lagoa
# Processing Record 36 of Set 8 | klaksvik
# Processing Record 37 of Set 8 | el alto
# Processing Record 38 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 8 | xai-xai
# Processing Record 40 of Set 8 | de aar
# Processing Record 41 of Set 8 | maraba
# Processing Record 42 of Set 8 | grajau
# Processing Record 43 of Set 8 | meadow lake
# Processing Record 44 of Set 8 | santa cruz
# Processing Record 45 of Set 8 | wukari
# Processing Record 46 of Set 8 | hofn
# Processing Record 47 of Set 8 | vila franca do campo
# Processing Record 48 of Set 8 | marzuq
# Processing Record 49 of Set 8 | murgab
# Processing Record 50 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 9 | sampit
# Processing Record 2 of Set 9 | nishihara
# Processing Record 3 of Set 9 | mackenzie
# Processing Record 4 of Set 9 | qui nhon
# Processing Record 5 of Set 9 | la grande
# Processing Record 6 of Set 9 | lazaro cardenas
# Processing Record 7 of Set 9 | namibe
# Processing Record 8 of Set 9 | san diego
# Processing Record 9 of Set 9 | charters towers
# Processing Record 10 of Set 9 | ixtapa
# Processing Record 11 of Set 9 | kabinda
# Processing Record 12 of Set 9 | reefton
# City not found. Skipping...
# Processing Record 13 of Set 9 | tura
# Processing Record 14 of Set 9 | parrita
# Processing Record 15 of Set 9 | burica
# City not found. Skipping...
# Processing Record 16 of Set 9 | kushmurun
# Processing Record 17 of Set 9 | areosa
# Processing Record 18 of Set 9 | praia da vitoria
# Processing Record 19 of Set 9 | pangody
# Processing Record 20 of Set 9 | tarabuco
# Processing Record 21 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 22 of Set 9 | east london
# Processing Record 23 of Set 9 | vuktyl
# Processing Record 24 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 9 | baracoa
# Processing Record 26 of Set 9 | bac lieu
# Processing Record 27 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 9 | noyabrsk
# Processing Record 29 of Set 9 | omsukchan
# Processing Record 30 of Set 9 | baker city
# Processing Record 31 of Set 9 | muzhi
# Processing Record 32 of Set 9 | sangmelima
# Processing Record 33 of Set 9 | berberati
# Processing Record 34 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 9 | sadao
# Processing Record 36 of Set 9 | yenangyaung
# Processing Record 37 of Set 9 | ugoofaaru
# Processing Record 38 of Set 9 | kapit
# Processing Record 39 of Set 9 | banes
# Processing Record 40 of Set 9 | namatanai
# Processing Record 41 of Set 9 | powell
# Processing Record 42 of Set 9 | new waterford
# Processing Record 43 of Set 9 | pratapgarh
# Processing Record 44 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 45 of Set 9 | weihe
# Processing Record 46 of Set 9 | beringovskiy
# Processing Record 47 of Set 9 | fort saint james
# Processing Record 48 of Set 9 | manicore
# Processing Record 49 of Set 9 | buraydah
# Processing Record 50 of Set 9 | aswan
# Processing Record 1 of Set 10 | olot
# Processing Record 2 of Set 10 | malmesbury
# Processing Record 3 of Set 10 | robertsport
# Processing Record 4 of Set 10 | tomatlan
# Processing Record 5 of Set 10 | izmalkovo
# Processing Record 6 of Set 10 | sonoita
# Processing Record 7 of Set 10 | mehamn
# Processing Record 8 of Set 10 | rabo de peixe
# Processing Record 9 of Set 10 | ryotsu
# Processing Record 10 of Set 10 | kitob
# Processing Record 11 of Set 10 | athabasca
# Processing Record 12 of Set 10 | clarence town
# Processing Record 13 of Set 10 | mount vernon
# Processing Record 14 of Set 10 | chaa-khol
# City not found. Skipping...
# Processing Record 15 of Set 10 | la ronge
# Processing Record 16 of Set 10 | hovd
# Processing Record 17 of Set 10 | chabahar
# Processing Record 18 of Set 10 | hukuntsi
# Processing Record 19 of Set 10 | presidente medici
# Processing Record 20 of Set 10 | galle
# Processing Record 21 of Set 10 | pilar
# Processing Record 22 of Set 10 | shirokiy
# Processing Record 23 of Set 10 | porto walter
# Processing Record 24 of Set 10 | consuegra
# Processing Record 25 of Set 10 | kirovskiy
# Processing Record 26 of Set 10 | pacific grove
# Processing Record 27 of Set 10 | butterworth
# Processing Record 28 of Set 10 | babol
# Processing Record 29 of Set 10 | pedernales
# Processing Record 30 of Set 10 | kavieng
# Processing Record 31 of Set 10 | atambua
# Processing Record 32 of Set 10 | cananeia
# Processing Record 33 of Set 10 | turayf
# Processing Record 34 of Set 10 | chillicothe
# Processing Record 35 of Set 10 | tongliao
# Processing Record 36 of Set 10 | ofaqim
# Processing Record 37 of Set 10 | lima
# Processing Record 38 of Set 10 | balikpapan
# Processing Record 39 of Set 10 | ascension
# Processing Record 40 of Set 10 | bideford
# Processing Record 41 of Set 10 | khingansk
# Processing Record 42 of Set 10 | souillac
# Processing Record 43 of Set 10 | barreiros
# Processing Record 44 of Set 10 | along
# Processing Record 45 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 46 of Set 10 | nakusp
# Processing Record 47 of Set 10 | egvekinot
# Processing Record 48 of Set 10 | honiara
# Processing Record 49 of Set 10 | liwale
# Processing Record 50 of Set 10 | sibi
# Processing Record 1 of Set 11 | knysna
# Processing Record 2 of Set 11 | ina
# Processing Record 3 of Set 11 | geraldton
# Processing Record 4 of Set 11 | borovskoy
# Processing Record 5 of Set 11 | damghan
# Processing Record 6 of Set 11 | naze
# Processing Record 7 of Set 11 | kozhva
# Processing Record 8 of Set 11 | bilibino
# Processing Record 9 of Set 11 | vila
# Processing Record 10 of Set 11 | coromandel
# Processing Record 11 of Set 11 | moss vale
# Processing Record 12 of Set 11 | bon accord
# Processing Record 13 of Set 11 | belison
# Processing Record 14 of Set 11 | turan
# Processing Record 15 of Set 11 | edea
# Processing Record 16 of Set 11 | quchan
# Processing Record 17 of Set 11 | bud
# Processing Record 18 of Set 11 | zhangye
# Processing Record 19 of Set 11 | telimele
# Processing Record 20 of Set 11 | polunochnoye
# Processing Record 21 of Set 11 | bushehr
# Processing Record 22 of Set 11 | aktau
# Processing Record 23 of Set 11 | broken hill
# Processing Record 24 of Set 11 | soyo
# Processing Record 25 of Set 11 | richards bay
# Processing Record 26 of Set 11 | cosala
# Processing Record 27 of Set 11 | neuquen
# Processing Record 28 of Set 11 | hobyo
# Processing Record 29 of Set 11 | mehriz
# Processing Record 30 of Set 11 | havelock
# Processing Record 31 of Set 11 | norilsk
# Processing Record 32 of Set 11 | axim
# Processing Record 33 of Set 11 | alice springs
# Processing Record 34 of Set 11 | chifeng
# Processing Record 35 of Set 11 | nizhniy ingash
# Processing Record 36 of Set 11 | gweta
# Processing Record 37 of Set 11 | svetlaya
# Processing Record 38 of Set 11 | terney
# Processing Record 39 of Set 11 | gamba
# Processing Record 40 of Set 11 | sabha
# Processing Record 41 of Set 11 | north myrtle beach
# Processing Record 42 of Set 11 | north platte
# Processing Record 43 of Set 11 | sao joao da barra
# Processing Record 44 of Set 11 | khandyga
# Processing Record 45 of Set 11 | mount pleasant
# Processing Record 46 of Set 11 | texarkana
# Processing Record 47 of Set 11 | huilong
# Processing Record 48 of Set 11 | pangnirtung
# Processing Record 49 of Set 11 | xingyi
# Processing Record 50 of Set 11 | peniche
# Processing Record 1 of Set 12 | nantucket
# Processing Record 2 of Set 12 | yefira
# City not found. Skipping...
# Processing Record 3 of Set 12 | jalu
# Processing Record 4 of Set 12 | puerto carreno
# Processing Record 5 of Set 12 | miandrivazo
# Processing Record 6 of Set 12 | scarborough
# Processing Record 7 of Set 12 | nueva loja
# Processing Record 8 of Set 12 | surin
# Processing Record 9 of Set 12 | zhigansk
# Processing Record 10 of Set 12 | oum hadjer
# Processing Record 11 of Set 12 | bathsheba
# Processing Record 12 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 13 of Set 12 | kunda
# Processing Record 14 of Set 12 | emerald
# Processing Record 15 of Set 12 | nabire
# Processing Record 16 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 17 of Set 12 | elizabeth city
# Processing Record 18 of Set 12 | burnie
# Processing Record 19 of Set 12 | farafangana
# Processing Record 20 of Set 12 | jacareacanga
# Processing Record 21 of Set 12 | chesterville
# Processing Record 22 of Set 12 | ashland
# Processing Record 23 of Set 12 | fatwa
# Processing Record 24 of Set 12 | hantsport
# Processing Record 25 of Set 12 | necochea
# Processing Record 26 of Set 12 | jumla
# Processing Record 27 of Set 12 | dunedin
# Processing Record 28 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 12 | lusaka
# Processing Record 30 of Set 12 | aykhal
# Processing Record 31 of Set 12 | sur
# Processing Record 32 of Set 12 | port blair
# Processing Record 33 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 34 of Set 12 | tigil
# Processing Record 35 of Set 12 | maragogi
# Processing Record 36 of Set 12 | sheridan
# Processing Record 37 of Set 12 | kisangani
# Processing Record 38 of Set 12 | pochutla
# Processing Record 39 of Set 12 | aksha
# Processing Record 40 of Set 12 | palmer
# Processing Record 41 of Set 12 | avera
# Processing Record 42 of Set 12 | touros
# Processing Record 43 of Set 12 | henties bay
# Processing Record 44 of Set 12 | mazatlan
# Processing Record 45 of Set 12 | muana
# Processing Record 46 of Set 12 | berlevag
# Processing Record 47 of Set 12 | valdivia
# Processing Record 48 of Set 12 | bocanda
# Processing Record 49 of Set 12 | sobolevo
# Processing Record 50 of Set 12 | chester
# Processing Record 1 of Set 13 | northam
# Processing Record 2 of Set 13 | kazachinskoye
# Processing Record 3 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 4 of Set 13 | sebinkarahisar
# Processing Record 5 of Set 13 | sapouy
# Processing Record 6 of Set 13 | inta
# Processing Record 7 of Set 13 | koslan
# Processing Record 8 of Set 13 | kalmunai
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Saskylakh  71.9167  114.0833     32.00        95         100
# 1       Rikitea -23.1203 -134.9692     75.54        78          11
# 2   Pietarsaari  63.6500   22.6833     44.01        65          99
# 3        Avarua -21.2078 -159.7750     82.45        83          75
# 4     Hithadhoo  -0.6000   73.0833     83.88        70          97
# 5        Barrow  71.2906 -156.7887     23.02        86         100
# 6     Carnarvon -24.8667  113.6333     70.27        56          40
# 7      Freeport  40.6576  -73.5832     91.38        68           0
# 8  Punta Arenas -53.1500  -70.9167     37.51        70          75
# 9       Cayenne   4.9333  -52.3333     82.09         1          20
#
#    Wind Speed Country                 Date
# 0        8.43      RU  2022-05-22 21:48:29
# 1       14.29      PF  2022-05-22 21:47:30
# 2        8.75      FI  2022-05-22 21:48:30
# 3       15.55      CK  2022-05-22 21:48:31
# 4       13.91      MV  2022-05-22 21:48:31
# 5        9.22      US  2022-05-22 21:48:32
# 6       15.64      AU  2022-05-22 21:48:33
# 7       18.41      US  2022-05-22 21:48:33
# 8        4.61      CL  2022-05-22 21:48:34
# 9        3.00      GF  2022-05-22 21:36:51

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
